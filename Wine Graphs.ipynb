# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Erika-Russi/mod_3_project/master/feature%20_engineering/Cleaned%20Data%20with%20States.csv"
df = pd.read_csv(url)
df= df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    Alcohol                                   Appellation Category  Points  \
# 0     14.9  Russian River Valley, Sonoma, California, US      Red      87
# 1     14.5  Central Coast, Central Coast, California, US      Red      87
# 2     13.8                           California Republic      Red      86
# 3     13.8          Lodi, Central Valley, California, US      Red      86
# 4     13.0                                New Jersey, US      Red      86
#
#    Price                                             Review  \
# 0  42.00  Baked plum, licorice and lavender aromas and f...
# 1  19.98  Pomegranate and light baking-spice aromas show...
# 2  15.00  Butter and vanilla notes dominate the jammy fr...
# 3  10.00  An aroma like toasted almonds and wood smoke m...
# 4  27.00  Plum skin and pomegranate lead the nose while ...
#
#                                                 Wine               Winery  \
# 0  V. Sattui 2015 Gilsson Vineyard Old Vine Zinfa...            V. Sattui
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = df.drop_duplicates('Review')

# %%
variety_df = df.groupby('Variety').filter(lambda x: len(x) > 75)
varieties = variety_df['Variety'].value_counts().index.tolist()
fig, ax = plt.subplots(figsize = (25, 10))
sns.countplot(x = variety_df['Variety'], order = varieties, ax = ax)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.countplot(df['Points'])

# %%
plt.figure(figsize=(60, 60))
data = df[df['Price'] < 1250]


x = sns.jointplot(x='Price', y='Points', data=data, height=12, ratio=8, color='maroon', kind='reg')

# %%
top_words = {'flavors': 2987, 'wine': 2345, 'aromas': 1989, 'palate': 1782, 'fruit': 1679, 'cherry': 1205, 'nose': 1203, 'black': 1031, 'finish': 1023, 'acidity': 968, 'oak': 866, 'tannins': 842, 'light': 711, 'ripe': 704, 'spice': 690, 'bottling': 676, 'red': 658, 'texture': 631, 'notes': 562, 'fresh': 556, 'apple': 541, 'dried': 512, 'white': 505, 'herb': 500, 'blackberry': 490, 'blend': 487, 'pepper': 480, 'lemon': 480, 'dark': 470, 'plum': 468, 'rich': 464, 'offers': 445, 'vanilla': 434, 'cabernet': 430, 'shows': 429, 'raspberry': 417, 'show': 414, 'well': 381, 'fullbodied': 374, 'soft': 374, 'strawberry': 369, 'full': 351, 'peach': 348, 'vineyard': 318, 'concentrated': 316, 'good': 312, 'bright': 310, 'sweet': 307, 'tart': 305, 'pear': 295, 'lead': 294, 'earthy': 290, 'touch': 290, 'green': 285, 'orange': 281, 'citrus': 281, 'new': 281, 'sauvignon': 280, 'flavor': 272, 'quite': 269, 'bit': 264, 'juicy': 260, 'followed': 255, 'balance': 250, 'tangy': 250, 'theres': 250, 'structure': 247, 'spicy': 244, 'chocolate': 239, 'bodied': 234, 'make': 233, 'cranberry': 230, 'berry': 230, 'firm': 230, 'made': 229, 'dry': 228, 'merlot': 227, 'savory': 227, 'lime': 226, 'balanced': 225, 'strong
'nearly': 35, 'despite': 35, 'mostly': 35, 'crme': 35, 'excellent': 35, 'mouthcoating': 35, 'family': 35, 'hold': 35, 'tone': 34, 'another': 34, 'youthful': 34, 'sorbet': 34, 'top': 34, 'classic': 34, 'milk': 34, 'value': 34, 'label': 34, 'reserved': 33, 'stand': 33, 'paste': 33, 'present': 33, 'peppercorn': 33, 'ride': 33, 'intrigue': 33, 'single': 33, 'table': 33, 'parts': 33, 'gris': 33, 'spent': 33, 'fore': 32, 'may': 32, 'rubber': 32, 'additional': 32, 'finegrained': 32, 'set': 32, 'varieties': 32, 'things': 32, 'edges': 32, 'pale': 32, 'mellow': 31, 'maple': 31, 'gravel': 31, 'hazelnut': 31, 'shy': 31, 'gritty': 31, 'perfumed': 31, 'rosemary': 31, 'earthiness': 31, 'reduction': 31, 'woven': 31, 'espresso': 31, 'price': 31, 'region': 31, 'work': 31, 'persist': 31, 'density': 31, 'pinch': 31, 'adding': 31, 'mushroom': 30, 'defined': 30, 'gentle': 30, 'brle': 30, 'loads': 30, 'snappy': 30, 'butterscotch': 30, 'bringing': 30, 'textural': 30, 'blackfruit': 30, 'remains': 30, 'going': 30, 'overripe': 29, 'papaya': 29, 'due': 29, 'heavy': 29, 'fill': 29, 'sauce': 29, 'subdued': 29, 'short': 29, 'plummy': 29, 'backdrop': 29, 'coolclimate': 29, 'firmly': 29, 'provides': 29, 'backbone': 29, 'feet': 29, 'tense': 29, 'dust': 29, 'brooding': 29}

# %%
top_words_above_150 = {k: v for k, v in top_words.items() if v > 150}

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud(stopwords=bad, background_color="black", width=400, height=200, font_step=4,
               max_words=142, relative_scaling=0.5, normalize_plurals=False).generate_from_frequencies(top_words_above_150)
plt.tick_params(axis='both', which='both', left=False, bottom=False, top=False, labelleft=False, labelbottom=False)
plt.figure(figsize=(60,20))
plt.imshow(wc)

# %%
top_white = {'oaky': 20,
 'yellow': 19,
 'apple': 100,
 'sweet': 16,
 'oak': 47,
 'aromas': 306,
 'pear': 64,
 'vanilla': 19,
 'lead': 16,
 'style': 16,
 'mediumbodied': 22,
 'peach': 73,
 'orange': 21,
 'nose': 116,
 'offers': 43,
 'fresh': 63,
 'flavors': 47,
 'lemon': 81,
 'floral': 48,
 'bright': 35,
 'earthy': 21,
 'aroma': 33,
 'strong': 20,
 'white': 138,
 'glass': 26,
 'notes': 35,
 'lime': 51,
 'light': 62,
 'flavor': 19,
 'ripe': 61,
 'creamy': 20,
 'bodied': 16,
 'spicy': 17,
 'riesling': 16,
 'sourced': 17,
 'fermented': 23,
 'new': 25,
 'vineyard': 34,
 'meet': 29,
 'crisp': 38,
 'rich': 33,
 'fruity': 28,
 'cream': 19,
 'crushed': 17,
 'full': 18,
 'fruit': 48,
 'bottling': 55,
 'citrus': 35,
 'grapefruit': 19,
 'shows': 19,
 'melon': 23,
 'wines': 19,
 'tightly': 20,
 'wound': 16,
 'wet': 22,
 'blend': 40,
 'made': 35,
 'reduced': 16,
 'pinot': 19,
 'fullbodied': 19,
 'stone': 21,
 'bit': 16,
 'texture': 16,
 'dry': 23,
 'quite': 22,
 'green': 20,
 'clean': 24,
 'aged': 21,
 'herb': 19,
 'vintage': 16,
 'honeysuckle': 17,
 'show': 20,
 'tropical': 17,
 'stainless': 16,}

# %%
wc_white = WordCloud(stopwords=bad, background_color="white", width=400, height=200, font_step=4,
               max_words=142, relative_scaling=0.5, normalize_plurals=False).generate_from_frequencies(top_white)
plt.figure(figsize=(60,20))
#plt.title(label='Frequency of Words in White Wine Reviews', fontdict={'fontsize':40})
plt.tick_params(axis='both', which='both', left=False, bottom=False, top=False, labelleft=False, labelbottom=False)
plt.grid(False)
plt.imshow(wc_white)

# %%
top_red = {'plum': 114,
 'aromas': 651,
 'flavors': 135,
 'light': 118,
 'show': 57,
 'vanilla': 85,
 'notes': 87,
 'fruit': 252,
 'aroma': 68,
 'wood': 42,
 'lead': 53,
 'nose': 158,
 'pepper': 71,
 'big': 56,
 'ripe': 125,
 'offers': 103,
 'blend': 223,
 'balance': 37,
 'cedar': 47,
 'fullbodied': 92,
 'soft': 50,
 'blueberry': 41,
 'blackberry': 108,
 'oak': 106,
 'fruity': 61,
 'shows': 79,
 'cherry': 244,
 'flavor': 36,
 'varietal': 61,
 'floral': 43,
 'quite': 41,
 'spice': 123,
 'tart': 36,
 'green': 48,
 'fresh': 73,
 'dried': 107,
 'earthy': 100,
 'tannic': 38,
 'strawberry': 42,
 'black': 245,
 'currant': 65,
 'mediumbodied': 44,
 'sweet': 47,
 'earth': 47,
 'raspberry': 70,
 'smoky': 46,
 'oaky': 37,
 'herb': 107,
 'dark': 133,
 'deep': 62,
 'color': 61,
 'glass': 38,
 'bottling': 140,
 'good': 36,
 'baking': 44,
 'spicy': 58,
 'bodied': 37,
 'rich': 99,
 'savory': 39,
 'vineyard': 117,
 'site': 51,
 'rose': 54,
 'winerys': 39,
 'estate': 48,
 'juicy': 48,
 'concentrated': 107,
 'bright': 46,
 'aged': 39,
 'roasted': 41,
 'dense': 44,
 'made': 71,
 'meet': 81,
 'pinot': 36,
 'grenache': 48,
 'anise': 36,
 'make': 44,
 'blended': 42,
 'full': 61,
 'vineyards': 38,
 'cranberry': 42,
 'thick': 60,
 'malbec': 44,
 'strong': 39,
 'new': 51,
 'berry': 41,
 'wines': 50}

# %%
wc_red = WordCloud(stopwords=bad, background_color="black", width=400, height=200, font_step=4,
               max_words=142, relative_scaling=0.5, normalize_plurals=False).generate_from_frequencies(top_red)
plt.figure(figsize=(20,10))
#plt.title(label='Frequency of Words in Red Wine Reviews', fontdict={'fontsize':40})
plt.tick_params(axis='both', which='both', left=False, bottom=False, top=False, labelleft=False, labelbottom=False)
plt.grid(False)
plt.imshow(wc_red)
