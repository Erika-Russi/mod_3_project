# %%
import pandas as pd
df = pd.read_csv('tabula-VintageChart_1970-2017.csv')
df
# Out:
#                       USA/CALIFORNIA Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0   NORTH COAST (CABERNET SAUVIGNON)         NT        98T        97E
# 1           NORTH COAST (CHARDONNAY)         NT        94E        96E
# 2            NORTH COAST (ZINFANDEL)         NT        93R        90I
# 3           NORTH COAST (PINOT NOIR)         NT        91R        87I
# 4         CENTRAL COAST: PASO ROBLES         NT         NT         NT
# 5                         USA/OREGON        NaN        NaN        NaN
# 6       WILLAMETTE VALLEY PINOT NOIR         NT        93R         NT
# 7                     USA/WASHINGTON        NaN        NaN        NaN
# 8           CABERNET SAUVIGNON/SYRAH         NT         NT         NT
# 9                                NaN        NaN        NaN        NaN
# 10                         ARGENTINA        92E        96I        91I
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# ...

# %%
df_first_10 = df.iloc[:,0:10]
df_first_10
# Out:
#                       USA/CALIFORNIA Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0   NORTH COAST (CABERNET SAUVIGNON)         NT        98T        97E
# 1           NORTH COAST (CHARDONNAY)         NT        94E        96E
# 2            NORTH COAST (ZINFANDEL)         NT        93R        90I
# 3           NORTH COAST (PINOT NOIR)         NT        91R        87I
# 4         CENTRAL COAST: PASO ROBLES         NT         NT         NT
# 5                         USA/OREGON        NaN        NaN        NaN
# 6       WILLAMETTE VALLEY PINOT NOIR         NT        93R         NT
# 7                     USA/WASHINGTON        NaN        NaN        NaN
# 8           CABERNET SAUVIGNON/SYRAH         NT         NT         NT
# 9                                NaN        NaN        NaN        NaN
# 10                         ARGENTINA        92E        96I        91I
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
df_csv= pd.read_csv('cleaned_vintage_chart_1.8.19.csv')
df_csv
# Out:
#         State             Region                   Variety 2017 2016 2015  \
# 0  California        NORTH COAST        CABERNET SAUVIGNON   NT  98T  97E
# 1  California        NORTH COAST                CHARDONNAY   NT  94E  96E
# 2  California        NORTH COAST                 ZINFANDEL   NT  93R  90I
# 3  California        NORTH COAST                PINOT NOIR   NT  91R  87I
# 4  California        PASO ROBLES               PASO ROBLES   NT   NT   NT
# 5  California      Santa Barbara             Santa Barbara   NT   NT   NT
# 6      Oregon  WILLAMETTE VALLEY                PINOT NOIR   NT  93R   NT
# 7  Washington         Washington  CABERNET SAUVIGNON/SYRAH   NT   NT   NT
#
#   2014 2013 2012 2011 2010 2009
# 0  93R  98T  96E  78I  95T  94T
# 1  94R  93R  94E  88I  91E  90R
# 2  93R  92R  92R  74I  90R  85I
# 3  94R  90R  93R  84I  91R  90R
# 4  93E  94R  90E  88E  92T  87R
# 5  94R  93R  93R  87E  92T  87R
# 6  93T  87R  92R  90R  88I  86R
# 7  94T  92T  95T  87E  92T  92T
