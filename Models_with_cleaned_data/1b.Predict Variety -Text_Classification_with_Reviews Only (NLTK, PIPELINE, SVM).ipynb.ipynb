# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Cleaned Data with States.csv')
df.head()
# Out:
#    Unnamed: 0  Alcohol                                   Appellation Category  \
# 0           0     14.9  Russian River Valley, Sonoma, California, US      Red
# 1           1     14.5  Central Coast, Central Coast, California, US      Red
# 2           2     13.8                           California Republic      Red
# 3           3     13.8          Lodi, Central Valley, California, US      Red
# 4           4     13.0                                New Jersey, US      Red
#
#    Points  Price                                             Review  \
# 0      87  42.00  Baked plum, licorice and lavender aromas and f...
# 1      87  19.98  Pomegranate and light baking-spice aromas show...
# 2      86  15.00  Butter and vanilla notes dominate the jammy fr...
# 3      86  10.00  An aroma like toasted almonds and wood smoke m...
# 4      86  27.00  Plum skin and pomegranate lead the nose while ...
#
#                                                 Wine               Winery  \
# 0  V. Sattui 2015 Gilsson Vineyard Old Vine Zinfa...            V. Sattui
# 1  Wente 2014 Coastal Selection Pinot Noir (Centr...                Wente
# 2  California Republic 2016 Cabernet Sauvignon (C...  California Republic
# 3     Collier Creek 2015 Red Wagon Pinot Noir (Lodi)        Collier Creek
# 4                  DiLuca 2016 Rosso Black Label Red               DiLuca
#
#      Year             Variety       State
# 0  2015.0           Zinfandel  California
# 1  2014.0          Pinot Noir  California
# 2  2016.0  Cabernet Sauvignon  California
# 3  2015.0          Pinot Noir  California
# 4  2016.0           Red Blend         NaN

# %% [markdown]
# # Potential target variables to Predict based on data above:
# - color: there are 3 unique colors
# - country: there are 7 unique countries
# - points - below mean or above mean?
# - price - below mean or above mean?
# - taster name - based on the language they used?
# - the variety of wine? - pinot noir etc (there are 434 total wine varieties)

# %%
len(df)
# Out:
# 4768

# %%
df.Variety.describe()
# Out:
# count           4768
# unique           117
# top       Pinot Noir
# freq            1058
# Name: Variety, dtype: object

# %%
# df.isna().sum()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Alcohol', 'Appellation', 'Category', 'Points', 'Price',
#        'Review', 'Wine', 'Winery', 'Year', 'Variety', 'State'],
#       dtype='object')

# %%
# region_2 and twitter handle have the most null values so dropping the column
df_cleaned1 = df.drop(['Unnamed: 0', 'Alcohol', 'Appellation', 'Points', 'Price', 'Wine', 'Winery', 'Year', 'Category', 'State'],axis=1)
df_cleaned1
# Out:
#                                                  Review  \
# 0     Baked plum, licorice and lavender aromas and f...
# 1     Pomegranate and light baking-spice aromas show...
# 2     Butter and vanilla notes dominate the jammy fr...
# 3     An aroma like toasted almonds and wood smoke m...
# 4     Plum skin and pomegranate lead the nose while ...
# 5     This is a big ripe red wine moderate in struct...
# 6     This wine is a blend of 48% Cabernet Sauvignon...
# 7     Honey-dipped pineapple and guava, with a touch...
# 8     Thick and oaky, this estate wine evokes carame...
# 9     With an ashy undercurrent of char and smoke, t...
# 10    Dusty with highlights of cedar and sage, this ...
# 11    Yellow apple and sweet oak aromas make for a p...
# 12    This is a full-bodied, boldly ripe Cabernet Sa...
# 13    Aromas of ripe blueberry and blackberry mingle...
# 14    Brawny fruit is overwhelmed by smoke and charr...
# 15    Pear, butter and vanilla aromas lead to a soft...
# 16    This is an easygoing, fruity wine that shows s...
# 17    This has a wealth of cherry cola flavor that b...
# 18    Floral and quite cherry-berry in fruity flavor...
# 19    Very extracted aromas of red currants and all ...
# 20    This big and rather tart wine has a green stre...
# 21    Rustic and hearty in style, this medium-bodied...
# 22    This wine has fresh fruit flavors and a fair s...
# 23    Boasting overripe aromas and flavors of raisin...
# 24    This is an austere, earthy and tannic red tang...
# 25    Aromas of green pepper, black currant, plum an...
# 26    Yellow peach and Mandarin orange peel are shy ...
# 27    This wine possesses a hearty helping of tannin...
# 28    An especially bright copper color make this wi...
# 29    This wine is a blend of 38% Merlot, 31% Cabern...
# ...                                                 ...
# 4738  Tropical fruits come through in abundance here...
# 4739  Fennel, herb, spice and boysenberry and black ...
# 4740  Deep red fruit meets with cedar and pepper dus...
# 4741  Nutmeg, baked cherry, Chinese five spice and c...
# 4742  Very light in the glass, this fresh bottling s...
# 4743  Sourced from 45-year-old vines, this is a crea...
# 4744  This wine's vanilla cream aromas waft from the...
# 4745  This deep rose-colored wine with silky cherry ...
# 4746  Vibrant jasmine, honeysuckle and peach aromas ...
# 4747  Hints of vanilla and milk chocolate dress up t...
# 4748  The winery's flagship Pinot Noir, this is a bl...
# 4749  Vibrant fruit flavors and a very firm tannic t...
# 4750  Dried blueberry, loamy soil, anise and roastin...
# 4751  Capturing the elegant aromas of both vineyard ...
# 4752  This wine's new French oak was reduced to 29% ...
# 4753  Stewed black plum, licorice and milk chocolate...
# 4754  This wine's appealing plum, barrel spice, smok...
# 4755  This big wine smells very potent and concentra...
# 4756  A robust component of smoky aromas and flavors...
# 4757  This giant of a wine has more than enough oaky...
# 4758  Sourced from a single vineyard, this vintage b...
# 4759  Pomelo skin, grapefruit zest, chalk and a bit ...
# 4760  Elegant Asian pear, apple blossoms and wet sto...
# 4761  This medium-bodied wine from Don Sebastiani & ...
# 4762  This stainless expression shows soft and suppl...
# 4763  This is bound to be controversial, because it ...
# 4764  This wine's juicy citrus flavors are amplified...
# 4765  This is a microscopic production, which shows ...
# 4766  The dank aroma of forest undergrowth meets wit...
# 4767  Big and beefy, this wine has huge aromas of wo...
#
#                             Variety
# 0                         Zinfandel
# 1                        Pinot Noir
# 2                Cabernet Sauvignon
# 3                        Pinot Noir
# 4                         Red Blend
# 5                        Pinot Noir
# 6                         Red Blend
# 7                   Sauvignon Blanc
# 8                        Chardonnay
# 9                        Sangiovese
# 10                   Cabernet Franc
# 11                       Chardonnay
# 12               Cabernet Sauvignon
# 13                           Merlot
# 14                        Zinfandel
# 15                       Chardonnay
# 16               Cabernet Sauvignon
# 17               Cabernet Sauvignon
# 18                        Zinfandel
# 19                       Pinot Noir
# 20                          Barbera
# 21    Spirit Canyon Vineyard Arneis
# 22               Cabernet Sauvignon
# 23                   Cabernet Franc
# 24                       Pinot Noir
# 25               Cabernet Sauvignon
# 26                      White Blend
# 27                           Merlot
# 28                             Rosé
# 29                        Red Blend
# ...                             ...
# 4738                       Viognier
# 4739                          Syrah
# 4740                      Carignane
# 4741                       Grenache
# 4742                Sauvignon Blanc
# 4743                     Chardonnay
# 4744                     Pinot Noir
# 4745                     Pinot Noir
# 4746                       Riesling
# 4747                          Syrah
# 4748                     Pinot Noir
# 4749                    Tempranillo
# 4750                   Petite Sirah
# 4751                     Pinot Noir
# 4752                     Pinot Noir
# 4753                      Red Blend
# 4754                   Petit Verdot
# 4755                         Tannat
# 4756                      Zinfandel
# 4757                     Chardonnay
# 4758                     Pinot Noir
# 4759                Sauvignon Blanc
# 4760                       Viognier
# 4761                     Pinot Noir
# 4762                       Albariño
# 4763                       Dolcetto
# 4764                Sauvignon Blanc
# 4765                     Pinot Noir
# 4766                     Pinot Noir
# 4767                         Merlot
#
# [4768 rows x 2 columns]

# %%
list(df_cleaned1.columns.values)
# Out:
# ['Review', 'Variety']

# %% [markdown]
# ## Word Vectorization

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
import nltk
np.random.seed(0)

# %%
df_cleaned1.Review
# Out:
# 0       Baked plum, licorice and lavender aromas and f...
# 1       Pomegranate and light baking-spice aromas show...
# 2       Butter and vanilla notes dominate the jammy fr...
# 3       An aroma like toasted almonds and wood smoke m...
# 4       Plum skin and pomegranate lead the nose while ...
# 5       This is a big ripe red wine moderate in struct...
# 6       This wine is a blend of 48% Cabernet Sauvignon...
# 7       Honey-dipped pineapple and guava, with a touch...
# 8       Thick and oaky, this estate wine evokes carame...
# 9       With an ashy undercurrent of char and smoke, t...
# 10      Dusty with highlights of cedar and sage, this ...
# 11      Yellow apple and sweet oak aromas make for a p...
# 12      This is a full-bodied, boldly ripe Cabernet Sa...
# 13      Aromas of ripe blueberry and blackberry mingle...
# 14      Brawny fruit is overwhelmed by smoke and charr...
# 15      Pear, butter and vanilla aromas lead to a soft...
# 16      This is an easygoing, fruity wine that shows s...
# 17      This has a wealth of cherry cola flavor that b...
# 18      Floral and quite cherry-berry in fruity flavor...
# 19      Very extracted aromas of red currants and all ...
# 20      This big and rather tart wine has a green stre...
# 21      Rustic and hearty in style, this medium-bodied...
# 22      This wine has fresh fruit flavors and a fair s...
# 23      Boasting overripe aromas and flavors of raisin...
# 24      This is an austere, earthy and tannic red tang...
# 25      Aromas of green pepper, black currant, plum an...
# 26      Yellow peach and Mandarin orange peel are shy ...
# 27      This wine possesses a hearty helping of tannin...
# 28      An especially bright copper color make this wi...
# 29      This wine is a blend of 38% Merlot, 31% Cabern...
#                               ...
# 4738    Tropical fruits come through in abundance here...
# 4739    Fennel, herb, spice and boysenberry and black ...
# 4740    Deep red fruit meets with cedar and pepper dus...
# 4741    Nutmeg, baked cherry, Chinese five spice and c...
# 4742    Very light in the glass, this fresh bottling s...
# 4743    Sourced from 45-year-old vines, this is a crea...
# 4744    This wine's vanilla cream aromas waft from the...
# 4745    This deep rose-colored wine with silky cherry ...
# 4746    Vibrant jasmine, honeysuckle and peach aromas ...
# 4747    Hints of vanilla and milk chocolate dress up t...
# 4748    The winery's flagship Pinot Noir, this is a bl...
# 4749    Vibrant fruit flavors and a very firm tannic t...
# 4750    Dried blueberry, loamy soil, anise and roastin...
# 4751    Capturing the elegant aromas of both vineyard ...
# 4752    This wine's new French oak was reduced to 29% ...
# 4753    Stewed black plum, licorice and milk chocolate...
# 4754    This wine's appealing plum, barrel spice, smok...
# 4755    This big wine smells very potent and concentra...
# 4756    A robust component of smoky aromas and flavors...
# 4757    This giant of a wine has more than enough oaky...
# 4758    Sourced from a single vineyard, this vintage b...
# 4759    Pomelo skin, grapefruit zest, chalk and a bit ...
# 4760    Elegant Asian pear, apple blossoms and wet sto...
# 4761    This medium-bodied wine from Don Sebastiani & ...
# 4762    This stainless expression shows soft and suppl...
# 4763    This is bound to be controversial, because it ...
# 4764    This wine's juicy citrus flavors are amplified...
# 4765    This is a microscopic production, which shows ...
# 4766    The dank aroma of forest undergrowth meets wit...
# 4767    Big and beefy, this wine has huge aromas of wo...
# Name: Review, Length: 4768, dtype: object

# %%
experiment_line= str(df_cleaned1.Review[2:3].values)
experiment_line
# Out:
# "['Butter and vanilla notes dominate the jammy fruit flavors in this rich and seemingly sweet wine. It is medium bodied, lightly tannic and heavily influenced by oaky aromas and flavors, including baking spices and maple syrup.']"

# %%
# experiment_line= df_cleaned4.description[2:3].to_string()

# clean_line = []
# # for word in experiment_line:

pattern = "([a-zA-Z]+(?:'[a-z]+)?)"
line_tokens_raw = nltk.regexp_tokenize(experiment_line, pattern)
print(line_tokens_raw)
# Out:
# ['Butter', 'and', 'vanilla', 'notes', 'dominate', 'the', 'jammy', 'fruit', 'flavors', 'in', 'this', 'rich', 'and', 'seemingly', 'sweet', 'wine', 'It', 'is', 'medium', 'bodied', 'lightly', 'tannic', 'and', 'heavily', 'influenced', 'by', 'oaky', 'aromas', 'and', 'flavors', 'including', 'baking', 'spices', 'and', 'maple', 'syrup']

# %%
reviews = str(df_cleaned1.Review[0:20].values)

# %%
reviews
# Out:
# '[\'Baked plum, licorice and lavender aromas and flavors define this jammy wine, which takes on a sweetness of oak. Thick on the midpalate, it has substantial weight from the tannins and powerfully ripe fruit.\'\n \'Pomegranate and light baking-spice aromas show on the mellow nose of this bottling. The palate is clean with fruit punch and spice-cake flavors wrapped in a fairly mellow texture.\'\n \'Butter and vanilla notes dominate the jammy fruit flavors in this rich and seemingly sweet wine. It is medium bodied, lightly tannic and heavily influenced by oaky aromas and flavors, including baking spices and maple syrup.\'\n "An aroma like toasted almonds and wood smoke meets spiced plum and red-cherry flavors in this medium-bodied wine. It\'s an oaky version that maintains pretty good balance."\n \'Plum skin and pomegranate lead the nose while white pepper and raw oak take on an earthy edge. The soft-bodied palate is awash in silky tannins, with intense flavors of vanilla, oak and green tobacco leaf over black cherry and plum. There is a spicy kick on the finish, with more vanilla and baked black plum.\'\n \'This is a big ripe red wine moderate in structure that offers fleshy mouthfuls of cola and black cherry.\'\n \'This wine is a blend of 48% Cabernet Sauvignon and 38% Merlot, with the balance Malbec and Petit Verdot. Aromas of mushroom, dried herb, wet gravel, spice and cherry lead to ripe cherry and soy flavors. The palate brings a sense of elegance and appeal.\'\n \'Honey-dipped pineapple and guava, with a touch of fig give this wine a fruity midpalate. This has a moderate structure and a lingering note of anise.\'\n \'Thick and oaky, this estate wine evokes caramel and pineapple-upside-down cake—its texture lushly unctuous and rich.\'\n \'With an ashy undercurrent of char and smoke, this wine offers medium-bodied layers of dried cherry and leather, finishing with a lasting note of black pepper.\'\n \'Dusty with highlights of cedar and sage, this full-bodied wine presents as somewhat dull on the palate—a soft, rounded and approachable expression of jammy blueberry.\'\n \'Yellow apple and sweet oak aromas make for a pleasant if not particularly complex aromatic entry to this bottling. Ripe apple and pear meet with sweet buttercream on the palate.\'\n \'This is a full-bodied, boldly ripe Cabernet Sauvignon. Soft layers of dark cherry and plum are well integrated and contrasted against dusty crushed rock and toasted oak.\'\n \'Aromas of ripe blueberry and blackberry mingle with vanilla and pumpkin spice on the nose. The fruit forward palate shows plum and cranberry backed by dried leaves, nutmeg and vanilla. The tannins are dusty yet structured, while the acidity is tied to the berry flavors and weaves in and out. It finishes with a tart berry flavor loaded with cracked pepper and earthy.\'\n \'Brawny fruit is overwhelmed by smoke and charred oak in this thickly tannic wine that has a jammy core of blackberry and marshmallow flavor.\'\n \'Pear, butter and vanilla aromas lead to a soft, rich texture and tasty fruit flavors. The wine is medium in weight, low in acidity and easy on the palate.\'\n \'This is an easygoing, fruity wine that shows sweet-oak aromas, a soft texture and candy-like flavors of cherries and raspberries. The body is medium, tannins are light and it finishes with a sense of sweetness.\'\n \'This has a wealth of cherry cola flavor that brushes up against varietal black currant and cedar. It takes on a lush brawny ripeness that overwhelms and opts for fruit flavor over structure.\'\n \'Floral and quite cherry-berry in fruity flavor, this wine has mild structure and generous tannin, with a midpalate bursting in earthy oak.\'\n \'Very extracted aromas of red currants and all spice show on the ripe nose of this bottling. Muddled plums and berries meet with spice cake on the rich palate.\']'

# %%
# categories = ['Red', 'White', 'Orange']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import *
stemmer = SnowballStemmer("english")

# %%
data = df_cleaned1
data
# Out:
#                                                  Review  \
# 0     Baked plum, licorice and lavender aromas and f...
# 1     Pomegranate and light baking-spice aromas show...
# 2     Butter and vanilla notes dominate the jammy fr...
# 3     An aroma like toasted almonds and wood smoke m...
# 4     Plum skin and pomegranate lead the nose while ...
# 5     This is a big ripe red wine moderate in struct...
# 6     This wine is a blend of 48% Cabernet Sauvignon...
# 7     Honey-dipped pineapple and guava, with a touch...
# 8     Thick and oaky, this estate wine evokes carame...
# 9     With an ashy undercurrent of char and smoke, t...
# 10    Dusty with highlights of cedar and sage, this ...
# 11    Yellow apple and sweet oak aromas make for a p...
# 12    This is a full-bodied, boldly ripe Cabernet Sa...
# 13    Aromas of ripe blueberry and blackberry mingle...
# 14    Brawny fruit is overwhelmed by smoke and charr...
# 15    Pear, butter and vanilla aromas lead to a soft...
# 16    This is an easygoing, fruity wine that shows s...
# 17    This has a wealth of cherry cola flavor that b...
# 18    Floral and quite cherry-berry in fruity flavor...
# 19    Very extracted aromas of red currants and all ...
# 20    This big and rather tart wine has a green stre...
# 21    Rustic and hearty in style, this medium-bodied...
# 22    This wine has fresh fruit flavors and a fair s...
# 23    Boasting overripe aromas and flavors of raisin...
# 24    This is an austere, earthy and tannic red tang...
# 25    Aromas of green pepper, black currant, plum an...
# 26    Yellow peach and Mandarin orange peel are shy ...
# 27    This wine possesses a hearty helping of tannin...
# 28    An especially bright copper color make this wi...
# 29    This wine is a blend of 38% Merlot, 31% Cabern...
# ...                                                 ...
# 4738  Tropical fruits come through in abundance here...
# 4739  Fennel, herb, spice and boysenberry and black ...
# 4740  Deep red fruit meets with cedar and pepper dus...
# 4741  Nutmeg, baked cherry, Chinese five spice and c...
# 4742  Very light in the glass, this fresh bottling s...
# 4743  Sourced from 45-year-old vines, this is a crea...
# 4744  This wine's vanilla cream aromas waft from the...
# 4745  This deep rose-colored wine with silky cherry ...
# 4746  Vibrant jasmine, honeysuckle and peach aromas ...
# 4747  Hints of vanilla and milk chocolate dress up t...
# 4748  The winery's flagship Pinot Noir, this is a bl...
# 4749  Vibrant fruit flavors and a very firm tannic t...
# 4750  Dried blueberry, loamy soil, anise and roastin...
# 4751  Capturing the elegant aromas of both vineyard ...
# 4752  This wine's new French oak was reduced to 29% ...
# 4753  Stewed black plum, licorice and milk chocolate...
# 4754  This wine's appealing plum, barrel spice, smok...
# 4755  This big wine smells very potent and concentra...
# 4756  A robust component of smoky aromas and flavors...
# 4757  This giant of a wine has more than enough oaky...
# 4758  Sourced from a single vineyard, this vintage b...
# 4759  Pomelo skin, grapefruit zest, chalk and a bit ...
# 4760  Elegant Asian pear, apple blossoms and wet sto...
# 4761  This medium-bodied wine from Don Sebastiani & ...
# 4762  This stainless expression shows soft and suppl...
# 4763  This is bound to be controversial, because it ...
# 4764  This wine's juicy citrus flavors are amplified...
# 4765  This is a microscopic production, which shows ...
# 4766  The dank aroma of forest undergrowth meets wit...
# 4767  Big and beefy, this wine has huge aromas of wo...
#
#                             Variety
# 0                         Zinfandel
# 1                        Pinot Noir
# 2                Cabernet Sauvignon
# 3                        Pinot Noir
# 4                         Red Blend
# 5                        Pinot Noir
# 6                         Red Blend
# 7                   Sauvignon Blanc
# 8                        Chardonnay
# 9                        Sangiovese
# 10                   Cabernet Franc
# 11                       Chardonnay
# 12               Cabernet Sauvignon
# 13                           Merlot
# 14                        Zinfandel
# 15                       Chardonnay
# 16               Cabernet Sauvignon
# 17               Cabernet Sauvignon
# 18                        Zinfandel
# 19                       Pinot Noir
# 20                          Barbera
# 21    Spirit Canyon Vineyard Arneis
# 22               Cabernet Sauvignon
# 23                   Cabernet Franc
# 24                       Pinot Noir
# 25               Cabernet Sauvignon
# 26                      White Blend
# 27                           Merlot
# 28                             Rosé
# 29                        Red Blend
# ...                             ...
# 4738                       Viognier
# 4739                          Syrah
# 4740                      Carignane
# 4741                       Grenache
# 4742                Sauvignon Blanc
# 4743                     Chardonnay
# 4744                     Pinot Noir
# 4745                     Pinot Noir
# 4746                       Riesling
# 4747                          Syrah
# 4748                     Pinot Noir
# 4749                    Tempranillo
# 4750                   Petite Sirah
# 4751                     Pinot Noir
# 4752                     Pinot Noir
# 4753                      Red Blend
# 4754                   Petit Verdot
# 4755                         Tannat
# 4756                      Zinfandel
# 4757                     Chardonnay
# 4758                     Pinot Noir
# 4759                Sauvignon Blanc
# 4760                       Viognier
# 4761                     Pinot Noir
# 4762                       Albariño
# 4763                       Dolcetto
# 4764                Sauvignon Blanc
# 4765                     Pinot Noir
# 4766                     Pinot Noir
# 4767                         Merlot
#
# [4768 rows x 2 columns]

# %%
numpy_array = data.as_matrix()
numpy_array
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([['Baked plum, licorice and lavender aromas and flavors define this jammy wine, which takes on a sweetness of oak. Thick on the midpalate, it has substantial weight from the tannins and powerfully ripe fruit.',
#         'Zinfandel'],
#        ['Pomegranate and light baking-spice aromas show on the mellow nose of this bottling. The palate is clean with fruit punch and spice-cake flavors wrapped in a fairly mellow texture.',
#         'Pinot Noir'],
#        ['Butter and vanilla notes dominate the jammy fruit flavors in this rich and seemingly sweet wine. It is medium bodied, lightly tannic and heavily influenced by oaky aromas and flavors, including baking spices and maple syrup.',
#         'Cabernet Sauvignon'],
#        ...,
#        ['This is a microscopic production, which shows itself to be medium bodied to full, with soft moderate structure. Dried cherry, raspberry and dried citrus round out the approachable, likable fruit-forwardness of the layered wine.',
#         'Pinot Noir'],
#        ['The dank aroma of forest undergrowth meets with campfire smoke and red currants on the nose of this appellation blend. The palate is lightweight in body though lively with flavors of wild berries and pine forest spice, bolstered by solid acidity.',
#         'Pinot Noir'],
#        ["Big and beefy, this wine has huge aromas of wood smoke, beef jus and cedar followed by generous blackberry and black-cherry flavors and a firm tannic texture. Earthy roasted elements indicate it's fully mature now.",
#         'Merlot']], dtype=object)

# %%
X = numpy_array[:,0]
Y = numpy_array[:,1]
Y
# Out:
# array(['Zinfandel', 'Pinot Noir', 'Cabernet Sauvignon', ..., 'Pinot Noir',
#        'Pinot Noir', 'Merlot'], dtype=object)

# %%
type(Y)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X)
X_train_counts.shape
# Out:
# (4768, 6721)

# %%
count_vect.vocabulary_.get(u'algorithm')

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
# Out:
# (4768, 6721)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (4768, 6721)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, Y)

# %%
target_names = list(set(Y))
target_names
# Out:
# ['Cabernet Sauvignon',
#  'Moscato',
#  'Elephant Mountain Vineyards',
#  'Barbera',
#  'Aglianico',
#  'Rosato',
#  'Petite Syrah',
#  'Primitivo',
#  'Petite',
#  'Falanghina',
#  'Gamay',
#  'Pinot Grigio',
#  'Aria White Port',
#  'Torrontés',
#  'Rosé',
#  "Nero d'Avola",
#  'Tannat',
#  'Spirit Canyon Vineyard Arneis',
#  'Red',
#  'Mourvèdre',
#  'White',
#  'Trousseau',
#  'Other White',
#  'Gewurztraminer',
#  'Petit Manseng',
#  'Gewürztraminer',
#  'Tempranillo',
#  'Chenin',
#  'Monastrell',
#  'Aleatico',
#  'Albariño',
#  'Sangiovese',
#  'Pinot Blanc',
#  'Rkatsiteli',
#  'Claudia',
#  'Valdiguié',
#  'Porton Norton',
#  'Zinfandel',
#  'Cabernet',
#  'Verdejo',
#  'Grenache Blanc',
#  'Port',
#  'Grenache Noir',
#  'Vidal Blanc',
#  'Auxerrois',
#  'Verdelho',
#  'Sauvignon Blanc',
#  'Pinotage',
#  'Swing',
#  'Semillon',
#  'Sin So Cinsault',
#  'Pinot Noir',
#  'Müller-Thurgau',
#  'Picpoul',
#  'Merlot',
#  'Pinot Gris',
#  'Sylvaner',
#  'Malbec',
#  'Sémillon',
#  'Melon de Bourgogne',
#  'Cabernet Franc',
#  'Cinsault',
#  'Teroldego',
#  'Mataro',
#  'Dolcetto',
#  'Gamay Noir',
#  'Malvasia Bianca',
#  'Chardonnay',
#  'Touriga Nacional',
#  'Pinot-Chardonnay',
#  'Vermentino',
#  'Orange Muscat',
#  'Traminette',
#  'Chenin Blanc',
#  'White Blend',
#  'Glenrose Vineyard Cinsault',
#  'McKinley Springs Vineyard Cinsault',
#  'Muscat',
#  'Grenache',
#  'Ugni Blanc',
#  'Royal Escort Paladini Vineyard Port',
#  'Seyval Blanc',
#  'Red Blend',
#  'G-S-M',
#  'Riesling',
#  'Limited Release Arneis',
#  'Rhône-style Red Blend',
#  'Durif',
#  'Negrette',
#  'Insight Marsanne',
#  'Grüner Veltliner',
#  'Champagne Blend',
#  'Semillon-Sauvignon Blanc',
#  'Nebbiolo',
#  'Violeta Portray Port',
#  'Carignane',
#  'Graziano Vineyard Arneis',
#  'Lagrein',
#  'Sauvignon',
#  'Claret',
#  'Montepulciano',
#  'Garnacha',
#  'Counoise',
#  'Petite Sirah',
#  'Fiano',
#  'Syrah',
#  'Meritage',
#  'Viognier',
#  'Estate Touriga Nacional',
#  'Cabernet Blend',
#  'Blaufränkisch',
#  'Lemberger',
#  'Seven Hills Vineyard',
#  'Sparkling Blend',
#  'Roussanne',
#  'Petit Verdot',
#  'Willow Creek Farm']

# %%
len(target_names)
# Out:
# 117

# %% [markdown]
# ## Build a Pipeline

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
('vect', CountVectorizer(stop_words='english')),
('tfidf', TfidfTransformer()),
('clf', MultinomialNB()),])

# %%
text_clf.fit(X_train, Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         ...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predicted = text_clf.predict(X_test)
np.mean(predicted == Y_test)
# Out:
# 0.4056603773584906

# %% [markdown]
# ## Use a SVM for better Accuracy

# %%
from sklearn.linear_model import SGDClassifier
text_clf = Pipeline([('vect', CountVectorizer(stop_words='english')),
                     ('tfidf', TfidfTransformer()),
                     ('clf', SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, random_state=42,
                                           max_iter=5, tol=None)),])

# %%
text_clf.fit(X_train, Y_train) 
predicted = text_clf.predict(X_test)
np.mean(predicted == Y_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# 0.5482180293501048

# %%
d = {'X_test': X_test, 'Y_test': Y_test,'Predicted': predicted}
results = pd.DataFrame(data=d)
results
# Out:
#                                                 X_test                 Y_test  \
# 0    Savory aromas of pepper, roast beef and hearty...                  Syrah
# 1    Prominent aromas of pear, peach and flower are...            White Blend
# 2    Aged in neutral puncheons, this wine has aroma...               Grenache
# 3    Lewis Vineyard makes up the majority of this w...                  Syrah
# 4    A touch of seeming-sweetness from generous oak...             Pinot Noir
# 5    Grown on the producer's Home Ranch, this offer...               Riesling
# 6    This bottling from the extremely coastal Jespe...        Sauvignon Blanc
# 7    This medium-bodied wine is fruity and relative...     Cabernet Sauvignon
# 8    Boysenberry, mocha, tar, roasted meat and mint...                  Syrah
# 9    This wine comes from a vineyard best known for...             Chardonnay
# 10   Spiced red apple and stone fruit aromas carry ...               Riesling
# 11   This is one of the more elegant and satisfying...             Pinot Noir
# 12   Chalky tannins wrap around sizable oak, sage, ...                 Merlot
# 13   Butterscotch and hazelnut aromas make for a ve...             Chardonnay
# 14   This blend of 52% Syrah, 31% Grenache, 11% Cou...  Rhône-style Red Blend
# 15   Light, floral and fragrant, this is a delicate...             Pinot Noir
# 16   This concentrated and detailed wine brings bla...             Pinot Noir
# 17   This oaky wine starts with spicy, earthy and w...             Pinot Noir
# 18   Fairly dark in the glass, this is an intense a...             Pinot Noir
# 19   Plump raspberries meet with wet soil, clay and...              Zinfandel
# 20   Blended with 18% Sémillon, this is a lush wine...        Sauvignon Blanc
# 21   Dark coffee, mocha, vanilla, cherry and herb a...     Cabernet Sauvignon
# 22   The aromas offer notes of baking spice, plum a...     Cabernet Sauvignon
# 23   Cut grass and pungent green-apple slices make ...        Sauvignon Blanc
# 24   This full-bodied wine amps up the butter and v...             Chardonnay
# 25   This wine is light-bodied and very straightfor...           Pinot Grigio
# 26   Expressive aromas of freshly cut red apple, pe...             Chardonnay
# 27   This wine is buttery in aroma and flavor and h...             Chardonnay
# 28   Fleshy and gravelly, this white is blended wit...        Sauvignon Blanc
# 29   Quite gamy and savory on the nose, this select...                  Syrah
# ..                                                 ...                    ...
# 924  No one in Oregon is more dedicated to this gra...         Cabernet Franc
# 925  Very crisp, lean and herbaceous, this light-bo...               Verdelho
# 926  Simple blue-fruit aromas define this rosé, wit...                   Rosé
# 927  Full bodied and firm textured, this wine offer...     Cabernet Sauvignon
# 928  Aromas and flavors of watermelon and strawberr...                   Rosé
# 929  Though made entirely in stainless steel, this ...             Pinot Gris
# 930  This is a delicious and substantial wine that ...             Chardonnay
# 931  The so-called Bunny Cuvée refers to the unname...             Pinot Noir
# 932  Ripe flavors and a round texture make this ful...             Pinot Noir
# 933  This wine saw only larger format new oak as we...             Chardonnay
# 934  Light leather and barnyard notes lead the way,...            Tempranillo
# 935  This wine is fruity, fresh and lengthy, with e...             Pinot Noir
# 936  From the exciting appellation that is Coombsvi...     Cabernet Sauvignon
# 937  Lemon balm, pink grapefruit pith and a touch o...             Chardonnay
# 938  A new offering from the winery, this is a blen...  Rhône-style Red Blend
# 939  Dark orange in color, this whole-cluster offer...             Pinot Noir
# 940  From two blocks of the vineyard planted to Pom...             Pinot Noir
# 941  Cherry, dried herbs and baked earth show on th...                 Merlot
# 942  With a touch of reduction in its tightly wound...             Pinot Noir
# 943  A matchstick aroma leads to crisp lemon and ap...             Chardonnay
# 944  This reserve is an excellent representation of...             Pinot Noir
# 945  Very shy aromas of black raspberry show on the...                  Syrah
# 946  Slightly sour cherry aromas meet with juniper ...             Pinot Noir
# 947  This early release from this vintage is a blen...              Red Blend
# 948  This white is rich and creamy, with a slight n...             Chardonnay
# 949  A sinewy nose leads the way to extracted flavo...     Cabernet Sauvignon
# 950  This is a lengthy and structured wine, made fr...             Pinot Noir
# 951  Structured in plenty of firm juicy acidity, th...             Chardonnay
# 952  This bottling is quite dense on the nose with ...             Pinot Noir
# 953  Lean and light aromas of pomegranate, tart str...             Pinot Noir
#
#                  Predicted
# 0                    Syrah
# 1               Chardonnay
# 2                   Merlot
# 3                    Syrah
# 4               Pinot Noir
# 5                 Viognier
# 6                    Syrah
# 7               Pinot Noir
# 8                    Syrah
# 9               Chardonnay
# 10                Riesling
# 11              Pinot Noir
# 12      Cabernet Sauvignon
# 13              Chardonnay
# 14   Rhône-style Red Blend
# 15              Pinot Noir
# 16              Pinot Noir
# 17              Pinot Noir
# 18              Pinot Noir
# 19      Cabernet Sauvignon
# 20         Sauvignon Blanc
# 21      Cabernet Sauvignon
# 22      Cabernet Sauvignon
# 23              Chardonnay
# 24              Chardonnay
# 25              Chardonnay
# 26              Pinot Gris
# 27              Chardonnay
# 28      Cabernet Sauvignon
# 29                   Syrah
# ..                     ...
# 924             Pinot Noir
# 925        Sauvignon Blanc
# 926             Pinot Noir
# 927             Chardonnay
# 928                   Rosé
# 929             Chardonnay
# 930             Chardonnay
# 931             Pinot Noir
# 932     Cabernet Sauvignon
# 933             Chardonnay
# 934              Red Blend
# 935             Pinot Noir
# 936     Cabernet Sauvignon
# 937             Chardonnay
# 938  Rhône-style Red Blend
# 939             Pinot Noir
# 940             Pinot Noir
# 941             Pinot Noir
# 942             Pinot Noir
# 943             Chardonnay
# 944             Pinot Noir
# 945             Pinot Noir
# 946             Pinot Noir
# 947              Red Blend
# 948             Chardonnay
# 949     Cabernet Sauvignon
# 950             Pinot Noir
# 951             Chardonnay
# 952             Pinot Noir
# 953             Pinot Noir
#
# [954 rows x 3 columns]

# %% [markdown]
# ## Try to predict the outcome on a new review

# %%
def predict_review(docs_new):
    X_new_counts = count_vect.transform(docs_new)
    X_new_tfidf = tfidf_transformer.transform(X_new_counts)
    predicted = clf.predict(X_new_tfidf)
    for doc, category in zip(docs_new, predicted):
        print('%r => %s' % (doc, category))

# %%
docs_new = ['buttery, goes well with fish', 'bold blackberry cherry smooth figs raisins caramel']

# %%
predict_review(docs_new)
# Out:
# 'buttery, goes well with fish' => Chardonnay
# 'bold blackberry cherry smooth figs raisins caramel' => Pinot Noir

# %%
predict_review(['refreshing','yellow'])
# Out:
# 'refreshing' => Pinot Noir
# 'yellow' => Chardonnay

# %%
predict_review(['red meat','harsh'])
# Out:
# 'red meat' => Pinot Noir
# 'harsh' => Cabernet Sauvignon

# %%
predict_review(['overly dry'])
# Out:
# 'overly dry' => Pinot Noir

# %%
predict_review(['grapey dry'])
# Out:
# 'grapey dry' => Red Blend

# %%
predict_review(['fermented'])
# Out:
# 'fermented' => Pinot Noir

# %%
predict_review(['tarte sweet'])
# Out:
# 'tarte sweet' => Pinot Noir

# %%
predict_review(['dark'])
# Out:
# 'dark' => Pinot Noir

# %%
predict_review(['slightly bitter earthier kick slightly dry light'])
# Out:
# 'slightly bitter earthier kick slightly dry light' => Pinot Noir

# %%
predict_review(['buttery light tarte'])
# Out:
# 'buttery light tarte' => Chardonnay

# %%
predict_review(['cat piss crisp citrus'])
# Out:
# 'cat piss crisp citrus' => Chardonnay

# %%
predict_review(['mineral'])
# Out:
# 'mineral' => Chardonnay

# %%
predict_review(['sweet fruity smooth'])
# Out:
# 'sweet fruity smooth' => Pinot Noir
